# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolas-Bernal/Inferencia-Estad-stica-/blob/main/Pruebas%20De%20Normalidad/Teorema_Del_Limite_Central.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inferencia estadistica
#
# ## Nicolas Bernal
#
# ### Pruebas De Normalidad
